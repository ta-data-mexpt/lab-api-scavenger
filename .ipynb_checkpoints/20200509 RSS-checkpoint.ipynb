# %%
import feedparser

# %%
wired=feedparser.parse('https://www.wired.com/feed/rss')

# %%
#print(wired)
wired.feed.keys()
# Out:
# dict_keys(['title', 'title_detail', 'subtitle', 'subtitle_detail', 'links', 'link', 'rights', 'rights_detail', 'language', 'updated', 'updated_parsed'])

# %%
len(wired.entries)
# Out:
# 50

# %%
for i in wired.entries:
    print(i.title)
# Out:
# The 5G Coronavirus Conspiracy Theory Has Taken a Dark Turn
# Space Photos of the Week: Europa\! Attempt No Landing There
# Zoom Security Gets a Boost With Keybase Acquisition
# 10 Best Wireless Earbuds WIRED Has Tried (True Wireless)
# *The Last Unicorn* Is a Work of Art
# Trump Guns for Chinese Telecoms but Doesn't Have a Real Plan
# 'Call of Duty: Modern Warfare 2' Is Still an Infuriating Relic
# 18 Last-Minute Mother's Day Gift Ideas and Deals (2020)
# Is Online Grocery Shopping Better for the Planet?
# 15 Best Weekend Deals: Headphones, Kitchen Essentials, and More
# 300 Drones Illuminate the Sky to Honor Health Care Workers
# Ways to Stay Calm During Quarantine: Candles, Plants, and Other Tips
# Watson's Creator Wants to Teach AI a New Trick: Common Sense
# Covid-19 Casts a Dark Cloud Over the Flying Car Future
# Microsoft Is Starting to Tease Xbox Series X Games
# Defcon Is Canceled
# The Year the Internet Thought I Was MacKenzie Bezos
# ...

# %%
import pandas as pd
df=pd.DataFrame(wired.entries)
df.head(10)
# Out:
#                                                title  \
# 0  The 5G Coronavirus Conspiracy Theory Has Taken...
# 1  Space Photos of the Week: Europa\! Attempt No ...
# 2  Zoom Security Gets a Boost With Keybase Acquis...
# 3  10 Best Wireless Earbuds WIRED Has Tried (True...
# 4                *The Last Unicorn* Is a Work of Art
# 5  Trump Guns for Chinese Telecoms but Doesn't Ha...
# 6  'Call of Duty: Modern Warfare 2' Is Still an I...
# 7  18 Last-Minute Mother's Day Gift Ideas and Dea...
# 8  Is Online Grocery Shopping Better for the Planet?
# 9  15 Best Weekend Deals: Headphones, Kitchen Ess...
#
#                                         title_detail  \
# 0  {'type': 'text/plain', 'language': None, 'base...
# 1  {'type': 'text/plain', 'language': None, 'base...
# 2  {'type': 'text/plain', 'language': None, 'base...
# 3  {'type': 'text/plain', 'language': None, 'base...
# 4  {'type': 'text/plain', 'language': None, 'base...
# 5  {'type': 'text/plain', 'language': None, 'base...
# ...
